# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_columns", None)
df = pd.read_csv("../datasets/raw/IndianWeatherRepository.csv")
print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
numerical_columns = df.select_dtypes(
    include=["int64", "float64"]
).columns
print("Numerical Features:", len(numerical_columns))
numerical_columns
# Out:
# Numerical Features: 30
# Index(['latitude', 'longitude', 'last_updated_epoch', 'temperature_celsius',
#        'temperature_fahrenheit', 'wind_mph', 'wind_kph', 'wind_degree',
#        'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity',
#        'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km',
#        'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
#        'air_quality_gb-defra-index', 'moon_illumination'],
#       dtype='str')

# %%
correlation_matrix = df[numerical_columns].corr()
correlation_matrix
# Out:
#                               latitude  longitude  last_updated_epoch  \
# latitude                      1.000000   0.076073            0.000538
# longitude                     0.076073   1.000000            0.001131
# last_updated_epoch            0.000538   0.001131            1.000000
# temperature_celsius          -0.490380  -0.106553           -0.100480
# temperature_fahrenheit       -0.490377  -0.106559           -0.100477
# wind_mph                     -0.179991  -0.260191            0.110483
# wind_kph                     -0.179829  -0.259883            0.110415
# wind_degree                  -0.026235  -0.022924           -0.002884
# pressure_mb                   0.186396  -0.018158            0.437818
# pressure_in                   0.187593  -0.018033            0.438146
# precip_mm                    -0.062708   0.042465           -0.135754
# precip_in                    -0.061577   0.042097           -0.134358
# humidity                     -0.303735   0.288879           -0.482745
# cloud                        -0.177401   0.135703           -0.286596
# feels_like_celsius           -0.519100  -0.086415           -0.177028
# feels_like_fahrenheit        -0.519091  -0.086442           -0.177101
# visibility_km                 0.132994  -0.099082            0.024022
# visibility_miles              0.137415  -0.092788            0.021078
# uv_index                      0.010608   0.067044           -0.201841
# gust_mph                     -0.102985  -0.275154            0.233565
# gust_kph                     -0.102954  -0.275102            0.233606
# air_quality_Carbon_Monoxide   0.273702   0.084059            0.012708
# air_quality_Ozone            -0.052471  -0.276584            0.464898
# air_quality_Nitrogen_dioxide  0.223746   0.030543            0.075932
# air_quality_Sulphur_dioxide   0.014896   0.037465            0.110136
# air_quality_PM2.5             0.274236   0.056177            0.045185
# air_quality_PM10              0.283878   0.044208            0.059255
# air_quality_us-epa-index      0.284087   0.043621            0.087477
# air_quality_gb-defra-index    0.245886   0.025552            0.071861
# moon_illumination             0.000198  -0.000797            0.059107
#
#                               temperature_celsius  temperature_fahrenheit  \
# latitude                                -0.490380               -0.490377
# longitude                               -0.106553               -0.106559
# last_updated_epoch                      -0.100480               -0.100477
# temperature_celsius                      1.000000                0.999990
# temperature_fahrenheit                   0.999990                1.000000
# wind_mph                                 0.275542                0.275549
# wind_kph                                 0.275325                0.275332
# wind_degree                              0.132329                0.132321
# pressure_mb                             -0.726573               -0.726576
# pressure_in                             -0.728150               -0.728153
# precip_mm                                0.054153                0.054149
# precip_in                                0.053682                0.053678
# humidity                                 0.031131                0.031109
# cloud                                    0.142739                0.142730
# feels_like_celsius                       0.983053                0.983053
# feels_like_fahrenheit                    0.983048                0.983054
# visibility_km                           -0.076158               -0.076158
# visibility_miles                        -0.083607               -0.083607
# uv_index                                 0.148815                0.148827
# gust_mph                                 0.225998                0.226005
# gust_kph                                 0.225925                0.225931
# air_quality_Carbon_Monoxide             -0.142655               -0.142667
# air_quality_Ozone                        0.038101                0.038095
# air_quality_Nitrogen_dioxide            -0.138767               -0.138761
# air_quality_Sulphur_dioxide              0.061207                0.061205
# air_quality_PM2.5                       -0.249943               -0.249971
# air_quality_PM10                        -0.222704               -0.222730
# air_quality_us-epa-index                -0.210257               -0.210277
# air_quality_gb-defra-index              -0.159768               -0.159781
# moon_illumination                        0.053337                0.053327
#
#                               wind_mph  wind_kph  wind_degree  pressure_mb  \
# latitude                     -0.179991 -0.179829    -0.026235     0.186396
# longitude                    -0.260191 -0.259883    -0.022924    -0.018158
# last_updated_epoch            0.110483  0.110415    -0.002884     0.437818
# temperature_celsius           0.275542  0.275325     0.132329    -0.726573
# temperature_fahrenheit        0.275549  0.275332     0.132321    -0.726576
# wind_mph                      1.000000  0.999923     0.122754    -0.204819
# wind_kph                      0.999923  1.000000     0.122158    -0.204831
# wind_degree                   0.122754  0.122158     1.000000    -0.151059
# pressure_mb                  -0.204819 -0.204831    -0.151059     1.000000
# pressure_in                  -0.205045 -0.205056    -0.150756     0.998303
# precip_mm                     0.052023  0.052153     0.006291    -0.157727
# precip_in                     0.051573  0.051699     0.006468    -0.156365
# humidity                     -0.117406 -0.117020    -0.097724    -0.245403
# cloud                         0.053109  0.053377    -0.036157    -0.320283
# feels_like_celsius            0.257788  0.257594     0.118569    -0.751413
# feels_like_fahrenheit         0.257815  0.257622     0.118586    -0.751451
# visibility_km                 0.163245  0.163060     0.102528    -0.000531
# visibility_miles              0.161718  0.161552     0.103948    -0.000174
# uv_index                      0.041566  0.041663     0.068966    -0.157738
# gust_mph                      0.861805  0.861335     0.091537    -0.104119
# gust_kph                      0.861816  0.861338     0.091543    -0.104053
# air_quality_Carbon_Monoxide  -0.213127 -0.213081    -0.021376     0.146337
# air_quality_Ozone             0.312461  0.312374     0.042870     0.175638
# air_quality_Nitrogen_dioxide -0.188559 -0.188507    -0.054543     0.178808
# air_quality_Sulphur_dioxide  -0.010884 -0.010769    -0.023004     0.013849
# air_quality_PM2.5            -0.228980 -0.229049     0.012885     0.260459
# air_quality_PM10             -0.223245 -0.223281     0.017645     0.249557
# air_quality_us-epa-index     -0.273312 -0.273468    -0.017557     0.282799
# air_quality_gb-defra-index   -0.264411 -0.264563    -0.046009     0.251501
# moon_illumination            -0.009252 -0.009400    -0.006007    -0.042975
#
#                               pressure_in  precip_mm  precip_in  humidity  \
# latitude                         0.187593  -0.062708  -0.061577 -0.303735
# longitude                       -0.018033   0.042465   0.042097  0.288879
# last_updated_epoch               0.438146  -0.135754  -0.134358 -0.482745
# temperature_celsius             -0.728150   0.054153   0.053682  0.031131
# temperature_fahrenheit          -0.728153   0.054149   0.053678  0.031109
# wind_mph                        -0.205045   0.052023   0.051573 -0.117406
# wind_kph                        -0.205056   0.052153   0.051699 -0.117020
# wind_degree                     -0.150756   0.006291   0.006468 -0.097724
# pressure_mb                      0.998303  -0.157727  -0.156365 -0.245403
# pressure_in                      1.000000  -0.157883  -0.156525 -0.247085
# precip_mm                       -0.157883   1.000000   0.999224  0.174144
# precip_in                       -0.156525   0.999224   1.000000  0.171667
# humidity                        -0.247085   0.174144   0.171667  1.000000
# cloud                           -0.320790   0.267060   0.261979  0.504358
# feels_like_celsius              -0.753123   0.076704   0.075921  0.134282
# feels_like_fahrenheit           -0.753162   0.076720   0.075938  0.134309
# visibility_km                    0.001885  -0.076036  -0.074880 -0.423871
# visibility_miles                 0.002287  -0.081051  -0.080033 -0.422875
# uv_index                        -0.158604   0.047931   0.047358  0.039691
# gust_mph                        -0.104708   0.027227   0.027530 -0.204095
# gust_kph                        -0.104642   0.027230   0.027534 -0.204104
# air_quality_Carbon_Monoxide      0.146330  -0.050391  -0.049544 -0.044208
# air_quality_Ozone                0.175642  -0.078021  -0.077291 -0.382301
# air_quality_Nitrogen_dioxide     0.178441  -0.050141  -0.049401 -0.087685
# air_quality_Sulphur_dioxide      0.013152  -0.014926  -0.014704 -0.055656
# air_quality_PM2.5                0.260902  -0.087764  -0.086434 -0.120632
# air_quality_PM10                 0.249883  -0.094712  -0.093281 -0.139088
# air_quality_us-epa-index         0.283358  -0.131192  -0.129365 -0.214547
# air_quality_gb-defra-index       0.251985  -0.135218  -0.133436 -0.223142
# moon_illumination               -0.042835   0.014724   0.014696 -0.038101
#
#                                  cloud  feels_like_celsius  \
# latitude                     -0.177401           -0.519100
# longitude                     0.135703           -0.086415
# last_updated_epoch           -0.286596           -0.177028
# temperature_celsius           0.142739            0.983053
# temperature_fahrenheit        0.142730            0.983053
# wind_mph                      0.053109            0.257788
# wind_kph                      0.053377            0.257594
# wind_degree                  -0.036157            0.118569
# pressure_mb                  -0.320283           -0.751413
# pressure_in                  -0.320790           -0.753123
# precip_mm                     0.267060            0.076704
# precip_in                     0.261979            0.075921
# humidity                      0.504358            0.134282
# cloud                         1.000000            0.200925
# feels_like_celsius            0.200925            1.000000
# feels_like_fahrenheit         0.200952            0.999991
# visibility_km                -0.276067           -0.106898
# visibility_miles             -0.275027           -0.114843
# uv_index                      0.056437            0.168632
# gust_mph                     -0.054088            0.189887
# gust_kph                     -0.054139            0.189814
# air_quality_Carbon_Monoxide  -0.134860           -0.139718
# air_quality_Ozone            -0.196396           -0.015161
# air_quality_Nitrogen_dioxide -0.124531           -0.141084
# air_quality_Sulphur_dioxide  -0.041242            0.053491
# air_quality_PM2.5            -0.247525           -0.251786
# air_quality_PM10             -0.263501           -0.228593
# air_quality_us-epa-index     -0.346217           -0.223676
# air_quality_gb-defra-index   -0.345811           -0.176123
# moon_illumination             0.006003            0.041694
#
#                               feels_like_fahrenheit  visibility_km  \
# latitude                                  -0.519091       0.132994
# longitude                                 -0.086442      -0.099082
# last_updated_epoch                        -0.177101       0.024022
# temperature_celsius                        0.983048      -0.076158
# temperature_fahrenheit                     0.983054      -0.076158
# wind_mph                                   0.257815       0.163245
# wind_kph                                   0.257622       0.163060
# wind_degree                                0.118586       0.102528
# pressure_mb                               -0.751451      -0.000531
# pressure_in                               -0.753162       0.001885
# precip_mm                                  0.076720      -0.076036
# precip_in                                  0.075938      -0.074880
# humidity                                   0.134309      -0.423871
# cloud                                      0.200952      -0.276067
# feels_like_celsius                         0.999991      -0.106898
# feels_like_fahrenheit                      1.000000      -0.106882
# visibility_km                             -0.106882       1.000000
# visibility_miles                          -0.114828       0.996877
# uv_index                                   0.168689       0.007449
# gust_mph                                   0.189906       0.036606
# gust_kph                                   0.189833       0.036660
# air_quality_Carbon_Monoxide               -0.139757      -0.149817
# air_quality_Ozone                         -0.015171       0.112112
# air_quality_Nitrogen_dioxide              -0.141112      -0.158578
# air_quality_Sulphur_dioxide                0.053465      -0.128258
# air_quality_PM2.5                         -0.251837      -0.055337
# air_quality_PM10                          -0.228645      -0.071093
# air_quality_us-epa-index                  -0.223733       0.009967
# air_quality_gb-defra-index                -0.176168       0.037324
# moon_illumination                          0.041665       0.005022
#
#                               visibility_miles  uv_index  gust_mph  gust_kph  \
# latitude                              0.137415  0.010608 -0.102985 -0.102954
# longitude                            -0.092788  0.067044 -0.275154 -0.275102
# last_updated_epoch                    0.021078 -0.201841  0.233565  0.233606
# temperature_celsius                  -0.083607  0.148815  0.225998  0.225925
# temperature_fahrenheit               -0.083607  0.148827  0.226005  0.225931
# wind_mph                              0.161718  0.041566  0.861805  0.861816
# wind_kph                              0.161552  0.041663  0.861335  0.861338
# wind_degree                           0.103948  0.068966  0.091537  0.091543
# pressure_mb                          -0.000174 -0.157738 -0.104119 -0.104053
# pressure_in                           0.002287 -0.158604 -0.104708 -0.104642
# precip_mm                            -0.081051  0.047931  0.027227  0.027230
# precip_in                            -0.080033  0.047358  0.027530  0.027534
# humidity                             -0.422875  0.039691 -0.204095 -0.204104
# cloud                                -0.275027  0.056437 -0.054088 -0.054139
# feels_like_celsius                   -0.114843  0.168632  0.189887  0.189814
# feels_like_fahrenheit                -0.114828  0.168689  0.189906  0.189833
# visibility_km                         0.996877  0.007449  0.036606  0.036660
# visibility_miles                      1.000000  0.006028  0.030413  0.030466
# uv_index                              0.006028  1.000000 -0.050911 -0.050913
# gust_mph                              0.030413 -0.050911  1.000000  0.999976
# gust_kph                              0.030466 -0.050913  0.999976  1.000000
# air_quality_Carbon_Monoxide          -0.154124 -0.045813 -0.151665 -0.151690
# air_quality_Ozone                     0.108333 -0.009373  0.378274  0.378268
# air_quality_Nitrogen_dioxide         -0.162979 -0.057779 -0.124117 -0.124123
# air_quality_Sulphur_dioxide          -0.132768  0.000050  0.023480  0.023454
# air_quality_PM2.5                    -0.057025 -0.055899 -0.161171 -0.161154
# air_quality_PM10                     -0.073563 -0.054291 -0.149288 -0.149271
# air_quality_us-epa-index              0.006981 -0.072863 -0.171188 -0.171182
# air_quality_gb-defra-index            0.034373 -0.071514 -0.159845 -0.159869
# moon_illumination                     0.003709  0.142647 -0.020188 -0.020172
#
#                               air_quality_Carbon_Monoxide  air_quality_Ozone  \
# latitude                                         0.273702          -0.052471
# longitude                                        0.084059          -0.276584
# last_updated_epoch                               0.012708           0.464898
# temperature_celsius                             -0.142655           0.038101
# temperature_fahrenheit                          -0.142667           0.038095
# wind_mph                                        -0.213127           0.312461
# wind_kph                                        -0.213081           0.312374
# wind_degree                                     -0.021376           0.042870
# pressure_mb                                      0.146337           0.175638
# pressure_in                                      0.146330           0.175642
# precip_mm                                       -0.050391          -0.078021
# precip_in                                       -0.049544          -0.077291
# humidity                                        -0.044208          -0.382301
# cloud                                           -0.134860          -0.196396
# feels_like_celsius                              -0.139718          -0.015161
# feels_like_fahrenheit                           -0.139757          -0.015171
# visibility_km                                   -0.149817           0.112112
# visibility_miles                                -0.154124           0.108333
# uv_index                                        -0.045813          -0.009373
# gust_mph                                        -0.151665           0.378274
# gust_kph                                        -0.151690           0.378268
# air_quality_Carbon_Monoxide                      1.000000          -0.315131
# air_quality_Ozone                               -0.315131           1.000000
# air_quality_Nitrogen_dioxide                     0.834517          -0.358865
# air_quality_Sulphur_dioxide                      0.506195          -0.029015
# air_quality_PM2.5                                0.843052          -0.174949
# air_quality_PM10                                 0.869185          -0.176745
# air_quality_us-epa-index                         0.661616          -0.091308
# air_quality_gb-defra-index                       0.506706          -0.039065
# moon_illumination                                0.007530           0.010880
#
#                               air_quality_Nitrogen_dioxide  \
# latitude                                          0.223746
# longitude                                         0.030543
# last_updated_epoch                                0.075932
# temperature_celsius                              -0.138767
# temperature_fahrenheit                           -0.138761
# wind_mph                                         -0.188559
# wind_kph                                         -0.188507
# wind_degree                                      -0.054543
# pressure_mb                                       0.178808
# pressure_in                                       0.178441
# precip_mm                                        -0.050141
# precip_in                                        -0.049401
# humidity                                         -0.087685
# cloud                                            -0.124531
# feels_like_celsius                               -0.141084
# feels_like_fahrenheit                            -0.141112
# visibility_km                                    -0.158578
# visibility_miles                                 -0.162979
# uv_index                                         -0.057779
# gust_mph                                         -0.124117
# gust_kph                                         -0.124123
# air_quality_Carbon_Monoxide                       0.834517
# air_quality_Ozone                                -0.358865
# air_quality_Nitrogen_dioxide                      1.000000
# air_quality_Sulphur_dioxide                       0.649868
# air_quality_PM2.5                                 0.632485
# air_quality_PM10                                  0.670794
# air_quality_us-epa-index                          0.520918
# air_quality_gb-defra-index                        0.415458
# moon_illumination                                 0.004547
#
#                               air_quality_Sulphur_dioxide  air_quality_PM2.5  \
# latitude                                         0.014896           0.274236
# longitude                                        0.037465           0.056177
# last_updated_epoch                               0.110136           0.045185
# temperature_celsius                              0.061207          -0.249943
# temperature_fahrenheit                           0.061205          -0.249971
# wind_mph                                        -0.010884          -0.228980
# wind_kph                                        -0.010769          -0.229049
# wind_degree                                     -0.023004           0.012885
# pressure_mb                                      0.013849           0.260459
# pressure_in                                      0.013152           0.260902
# precip_mm                                       -0.014926          -0.087764
# precip_in                                       -0.014704          -0.086434
# humidity                                        -0.055656          -0.120632
# cloud                                           -0.041242          -0.247525
# feels_like_celsius                               0.053491          -0.251786
# feels_like_fahrenheit                            0.053465          -0.251837
# visibility_km                                   -0.128258          -0.055337
# visibility_miles                                -0.132768          -0.057025
# uv_index                                         0.000050          -0.055899
# gust_mph                                         0.023480          -0.161171
# gust_kph                                         0.023454          -0.161154
# air_quality_Carbon_Monoxide                      0.506195           0.843052
# air_quality_Ozone                               -0.029015          -0.174949
# air_quality_Nitrogen_dioxide                     0.649868           0.632485
# air_quality_Sulphur_dioxide                      1.000000           0.351400
# air_quality_PM2.5                                0.351400           1.000000
# air_quality_PM10                                 0.380868           0.991601
# air_quality_us-epa-index                         0.268185           0.843950
# air_quality_gb-defra-index                       0.216580           0.657722
# moon_illumination                                0.005443           0.024484
#
#                               air_quality_PM10  air_quality_us-epa-index  \
# latitude                              0.283878                  0.284087
# longitude                             0.044208                  0.043621
# last_updated_epoch                    0.059255                  0.087477
# temperature_celsius                  -0.222704                 -0.210257
# temperature_fahrenheit               -0.222730                 -0.210277
# wind_mph                             -0.223245                 -0.273312
# wind_kph                             -0.223281                 -0.273468
# wind_degree                           0.017645                 -0.017557
# pressure_mb                           0.249557                  0.282799
# pressure_in                           0.249883                  0.283358
# precip_mm                            -0.094712                 -0.131192
# precip_in                            -0.093281                 -0.129365
# humidity                             -0.139088                 -0.214547
# cloud                                -0.263501                 -0.346217
# feels_like_celsius                   -0.228593                 -0.223676
# feels_like_fahrenheit                -0.228645                 -0.223733
# visibility_km                        -0.071093                  0.009967
# visibility_miles                     -0.073563                  0.006981
# uv_index                             -0.054291                 -0.072863
# gust_mph                             -0.149288                 -0.171188
# gust_kph                             -0.149271                 -0.171182
# air_quality_Carbon_Monoxide           0.869185                  0.661616
# air_quality_Ozone                    -0.176745                 -0.091308
# air_quality_Nitrogen_dioxide          0.670794                  0.520918
# air_quality_Sulphur_dioxide           0.380868                  0.268185
# air_quality_PM2.5                     0.991601                  0.843950
# air_quality_PM10                      1.000000                  0.837933
# air_quality_us-epa-index              0.837933                  1.000000
# air_quality_gb-defra-index            0.654516                  0.913403
# moon_illumination                     0.027588                  0.001091
#
#                               air_quality_gb-defra-index  moon_illumination
# latitude                                        0.245886           0.000198
# longitude                                       0.025552          -0.000797
# last_updated_epoch                              0.071861           0.059107
# temperature_celsius                            -0.159768           0.053337
# temperature_fahrenheit                         -0.159781           0.053327
# wind_mph                                       -0.264411          -0.009252
# wind_kph                                       -0.264563          -0.009400
# wind_degree                                    -0.046009          -0.006007
# pressure_mb                                     0.251501          -0.042975
# pressure_in                                     0.251985          -0.042835
# precip_mm                                      -0.135218           0.014724
# precip_in                                      -0.133436           0.014696
# humidity                                       -0.223142          -0.038101
# cloud                                          -0.345811           0.006003
# feels_like_celsius                             -0.176123           0.041694
# feels_like_fahrenheit                          -0.176168           0.041665
# visibility_km                                   0.037324           0.005022
# visibility_miles                                0.034373           0.003709
# uv_index                                       -0.071514           0.142647
# gust_mph                                       -0.159845          -0.020188
# gust_kph                                       -0.159869          -0.020172
# air_quality_Carbon_Monoxide                     0.506706           0.007530
# air_quality_Ozone                              -0.039065           0.010880
# air_quality_Nitrogen_dioxide                    0.415458           0.004547
# air_quality_Sulphur_dioxide                     0.216580           0.005443
# air_quality_PM2.5                               0.657722           0.024484
# air_quality_PM10                                0.654516           0.027588
# air_quality_us-epa-index                        0.913403           0.001091
# air_quality_gb-defra-index                      1.000000          -0.021654
# moon_illumination                              -0.021654           1.000000

# %%
plt.figure(figsize=(18,14))

sns.heatmap(
    correlation_matrix,
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Heatmap")
plt.show()

# %%
strong_positive = []

for col1 in correlation_matrix.columns:
    for col2 in correlation_matrix.columns:
        if col1 != col2:
            corr = correlation_matrix.loc[col1, col2]

            if corr > 0.80:
                strong_positive.append(
                    [col1, col2, round(corr,3)]
                )

strong_positive_df = pd.DataFrame(
    strong_positive,
    columns=["Feature1","Feature2","Correlation"]
)

strong_positive_df.drop_duplicates()
# Out:
#                         Feature1                      Feature2  Correlation
# 0            temperature_celsius        temperature_fahrenheit        1.000
# 1            temperature_celsius            feels_like_celsius        0.983
# 2            temperature_celsius         feels_like_fahrenheit        0.983
# 3         temperature_fahrenheit           temperature_celsius        1.000
# 4         temperature_fahrenheit            feels_like_celsius        0.983
# 5         temperature_fahrenheit         feels_like_fahrenheit        0.983
# 6                       wind_mph                      wind_kph        1.000
# 7                       wind_mph                      gust_mph        0.862
# 8                       wind_mph                      gust_kph        0.862
# 9                       wind_kph                      wind_mph        1.000
# 10                      wind_kph                      gust_mph        0.861
# 11                      wind_kph                      gust_kph        0.861
# 12                   pressure_mb                   pressure_in        0.998
# 13                   pressure_in                   pressure_mb        0.998
# 14                     precip_mm                     precip_in        0.999
# 15                     precip_in                     precip_mm        0.999
# 16            feels_like_celsius           temperature_celsius        0.983
# 17            feels_like_celsius        temperature_fahrenheit        0.983
# 18            feels_like_celsius         feels_like_fahrenheit        1.000
# 19         feels_like_fahrenheit           temperature_celsius        0.983
# 20         feels_like_fahrenheit        temperature_fahrenheit        0.983
# 21         feels_like_fahrenheit            feels_like_celsius        1.000
# 22                 visibility_km              visibility_miles        0.997
# 23              visibility_miles                 visibility_km        0.997
# 24                      gust_mph                      wind_mph        0.862
# 25                      gust_mph                      wind_kph        0.861
# 26                      gust_mph                      gust_kph        1.000
# 27                      gust_kph                      wind_mph        0.862
# 28                      gust_kph                      wind_kph        0.861
# 29                      gust_kph                      gust_mph        1.000
# 30   air_quality_Carbon_Monoxide  air_quality_Nitrogen_dioxide        0.835
# 31   air_quality_Carbon_Monoxide             air_quality_PM2.5        0.843
# 32   air_quality_Carbon_Monoxide              air_quality_PM10        0.869
# 33  air_quality_Nitrogen_dioxide   air_quality_Carbon_Monoxide        0.835
# 34             air_quality_PM2.5   air_quality_Carbon_Monoxide        0.843
# 35             air_quality_PM2.5              air_quality_PM10        0.992
# 36             air_quality_PM2.5      air_quality_us-epa-index        0.844
# 37              air_quality_PM10   air_quality_Carbon_Monoxide        0.869
# 38              air_quality_PM10             air_quality_PM2.5        0.992
# 39              air_quality_PM10      air_quality_us-epa-index        0.838
# 40      air_quality_us-epa-index             air_quality_PM2.5        0.844
# 41      air_quality_us-epa-index              air_quality_PM10        0.838
# 42      air_quality_us-epa-index    air_quality_gb-defra-index        0.913
# 43    air_quality_gb-defra-index      air_quality_us-epa-index        0.913

# %%
strong_negative = []

for col1 in correlation_matrix.columns:
    for col2 in correlation_matrix.columns:
        if col1 != col2:

            corr = correlation_matrix.loc[col1,col2]

            if corr < -0.50:
                strong_negative.append(
                    [col1,col2,round(corr,3)]
                )
strong_negative_df = pd.DataFrame(
    strong_negative,
    columns=["Feature1","Feature2","Correlation"]
)

strong_negative_df.drop_duplicates()
# Out:
#                   Feature1                Feature2  Correlation
# 0                 latitude      feels_like_celsius       -0.519
# 1                 latitude   feels_like_fahrenheit       -0.519
# 2      temperature_celsius             pressure_mb       -0.727
# 3      temperature_celsius             pressure_in       -0.728
# 4   temperature_fahrenheit             pressure_mb       -0.727
# 5   temperature_fahrenheit             pressure_in       -0.728
# 6              pressure_mb     temperature_celsius       -0.727
# 7              pressure_mb  temperature_fahrenheit       -0.727
# 8              pressure_mb      feels_like_celsius       -0.751
# 9              pressure_mb   feels_like_fahrenheit       -0.751
# 10             pressure_in     temperature_celsius       -0.728
# 11             pressure_in  temperature_fahrenheit       -0.728
# 12             pressure_in      feels_like_celsius       -0.753
# 13             pressure_in   feels_like_fahrenheit       -0.753
# 14      feels_like_celsius                latitude       -0.519
# 15      feels_like_celsius             pressure_mb       -0.751
# 16      feels_like_celsius             pressure_in       -0.753
# 17   feels_like_fahrenheit                latitude       -0.519
# 18   feels_like_fahrenheit             pressure_mb       -0.751
# 19   feels_like_fahrenheit             pressure_in       -0.753

# %%
rainfall_corr = correlation_matrix["precip_mm"]

rainfall_corr.sort_values(
    ascending=False
)
# Out:
# precip_mm                       1.000000
# precip_in                       0.999224
# cloud                           0.267060
# humidity                        0.174144
# feels_like_fahrenheit           0.076720
# feels_like_celsius              0.076704
# temperature_celsius             0.054153
# temperature_fahrenheit          0.054149
# wind_kph                        0.052153
# wind_mph                        0.052023
# uv_index                        0.047931
# longitude                       0.042465
# gust_kph                        0.027230
# gust_mph                        0.027227
# moon_illumination               0.014724
# wind_degree                     0.006291
# air_quality_Sulphur_dioxide    -0.014926
# air_quality_Nitrogen_dioxide   -0.050141
# air_quality_Carbon_Monoxide    -0.050391
# latitude                       -0.062708
# visibility_km                  -0.076036
# air_quality_Ozone              -0.078021
# visibility_miles               -0.081051
# air_quality_PM2.5              -0.087764
# air_quality_PM10               -0.094712
# air_quality_us-epa-index       -0.131192
# air_quality_gb-defra-index     -0.135218
# last_updated_epoch             -0.135754
# pressure_mb                    -0.157727
# pressure_in                    -0.157883
# Name: precip_mm, dtype: float64

# %%
heatwave_corr = correlation_matrix[
    "feels_like_celsius"
]
heatwave_corr.sort_values(
    ascending=False
)
# Out:
# feels_like_celsius              1.000000
# feels_like_fahrenheit           0.999991
# temperature_celsius             0.983053
# temperature_fahrenheit          0.983053
# wind_mph                        0.257788
# wind_kph                        0.257594
# cloud                           0.200925
# gust_mph                        0.189887
# gust_kph                        0.189814
# uv_index                        0.168632
# humidity                        0.134282
# wind_degree                     0.118569
# precip_mm                       0.076704
# precip_in                       0.075921
# air_quality_Sulphur_dioxide     0.053491
# moon_illumination               0.041694
# air_quality_Ozone              -0.015161
# longitude                      -0.086415
# visibility_km                  -0.106898
# visibility_miles               -0.114843
# air_quality_Carbon_Monoxide    -0.139718
# air_quality_Nitrogen_dioxide   -0.141084
# air_quality_gb-defra-index     -0.176123
# last_updated_epoch             -0.177028
# air_quality_us-epa-index       -0.223676
# air_quality_PM10               -0.228593
# air_quality_PM2.5              -0.251786
# latitude                       -0.519100
# pressure_mb                    -0.751413
# pressure_in                    -0.753123
# Name: feels_like_celsius, dtype: float64

# %%
redundant_features = [
    "temperature_fahrenheit",
    "wind_mph",
    "pressure_in",
    "precip_in",
    "visibility_miles",
    "gust_mph"
]
df[redundant_features].head()
# Out:
#    temperature_fahrenheit  wind_mph  pressure_in  precip_in  visibility_miles  \
# 0                    81.5      12.8        29.77        0.0                 6
# 1                    81.5       9.6        29.78        0.0                 6
# 2                    79.3      11.4        29.78        0.0                 6
# 3                    78.1      10.5        29.80        0.0                 6
# 4                    81.0      10.1        29.79        0.0                 6
#
#    gust_mph
# 0      14.8
# 1      11.2
# 2      13.2
# 3      13.0
# 4      11.6

# %%
print("""
CORRELATION ANALYSIS REPORT
1. Strong positive correlations identified.
2. Strong negative correlations identified.
3. Rainfall predictor relationships analyzed.
4. Heatwave predictor relationships analyzed.
5. Redundant features identified.
6. Multicollinearity assessment completed.
7. Dataset is ready for preprocessing.
8. Candidate features finalized for:
   - Clustering
   - Anomaly Detection
   - Rainfall Prediction
   - Heatwave Prediction
""")
# Out:
# CORRELATION ANALYSIS REPORT
# 1. Strong positive correlations identified.
# 2. Strong negative correlations identified.
# 3. Rainfall predictor relationships analyzed.
# 4. Heatwave predictor relationships analyzed.
# 5. Redundant features identified.
# 6. Multicollinearity assessment completed.
# 7. Dataset is ready for preprocessing.
# 8. Candidate features finalized for:
#    - Clustering
#    - Anomaly Detection
#    - Rainfall Prediction
#    - Heatwave Prediction
